# %% [markdown]
# # Домашнее задание: декораторы

# %% [markdown]
# ## Импорт библиотек, установка констант

# %%
import requests
import time
import re

from random import randint

# %%
BOOK_PATH = 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %% [markdown]
# ## Задание 1
# Реализуйте декоратор benchmark(func), выводящий время, которое заняло выполнение декорируемой функции

# %%
def benchmark(func):
    """
    Декоратор, выводящий время, которое заняло выполнение декорируемой функции
    """

    def wrapper(*args, **kwargs):
        begin = time.time()
        now = func(*args, **kwargs)
        end = time.time()
        print(f'Занятое время функции {func.__name__}: {end-begin} секунд')
        return now
    return wrapper

# %% [markdown]
# ## Задание 2
# Реализуйте декоратор logging(func), который выводит параметры с которыми была вызвана функция

# %%
def logging(func):
    """
    Декоратор, который выводит параметры с которыми была вызвана функция
    """

    def wrapper(*args, **kwargs):
        print(f'Функция {func.__name__} была вызвана с аргументом {args} и {kwargs}')
        return func(*args, **kwargs)
    return wrapper

# %% [markdown]
# ## Задание 3
# Реализуйте декоратор counter(func), считающий и выводящий количество вызовов декорируемой функции

# %%
def counter(func):
    """
    Декоратор, считающий и выводящий количество вызовов декорируемой функции
    """
    func.counter = 0
    def wrapper(*args, **kwargs):
        func.counter += 1
        print(f'Функция {func.__name__} была вызвана {func.counter} раз(а)')
        return func(*args, **kwargs)
    return wrapper

# %% [markdown]
# ## Задание 4
# Реализуйте декоратор memo(func), запоминающий результаты исполнения функции func, чьи аргументы *args должны быть хешируемыми. Сравните время выполнения рекурсивной реализации расчета чисел Фибоначчи без декоратора и с ним

# %%
def memo(func):
  """
  Декоратор, запоминающий результаты исполнения функции func, чьи аргументы args должны быть хешируемыми
  """
  cache = {}

  def fmemo(*args):
    if args not in cache:
      cache[args] = func(*args)
    return cache[args]
  fmemo.cache = cache
  return fmemo

# %% [markdown]
# ## Тестирование

# %%
@counter
@logging
@benchmark
def word_count(word, url=BOOK_PATH):
    """
    Функция для посчета указанного слова на html-странице
    """

    # отправляем запрос в библиотеку Gutenberg и забираем текст
    raw = requests.get(url).text

    # заменяем в тексте все небуквенные символы на пробелы
    processed_book = re.sub('[\W]+' , ' ', raw).lower()

    # считаем
    cnt = len(re.findall(word.lower(), processed_book))

    return f"Cлово {word} встречается {cnt} раз"

print(word_count('whole'))
# Out:
# Функция wrapper была вызвана 1 раз(а)
# Функция wrapper была вызвана с аргументом ('whole',) и {}
# Занятое время функции word_count: 0.9439697265625 секунд
# Cлово whole встречается 176 раз

# %%
@benchmark
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
import functools

def benchmark(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f'Время выполнения функции {func.__name__}: {end - start} секунд')
        return result
    return wrapper

result = fib(10)
print(result)
# Out:
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 9.5367431640625e-07 секунд
# Время выполнения функции fib: 0.00011181831359863281 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 3.886222839355469e-05 секунд
# Время выполнения функции fib: 7.772445678710938e-05 секунд
# Время выполнения функции fib: 0.00023746490478515625 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 3.5762786865234375e-05 секунд
# Время выполнения функции fib: 7.367134094238281e-05 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.0531158447265625e-05 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 3.7670135498046875e-05 секунд
# Время выполнения функции fib: 7.486343383789062e-05 секунд
# Время выполнения функции fib: 0.00015234947204589844 секунд
# Время выполнения функции fib: 0.0002620220184326172 секунд
# Время выполнения функции fib: 0.0005481243133544922 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 3.5762786865234375e-05 секунд
# Время выполнения функции fib: 7.224082946777344e-05 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 3.647804260253906e-05 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 3.552436828613281e-05 секунд
# Время выполнения функции fib: 7.152557373046875e-05 секунд
# Время выполнения функции fib: 0.00014209747314453125 секунд
# Время выполнения функции fib: 0.00024890899658203125 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 3.814697265625e-05 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 3.7670135498046875e-05 секунд
# Время выполнения функции fib: 7.653236389160156e-05 секунд
# Время выполнения функции fib: 0.00016427040100097656 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 3.5762786865234375e-05 секунд
# Время выполнения функции fib: 7.200241088867188e-05 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.029273986816406e-05 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 9.5367431640625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 3.981590270996094e-05 секунд
# Время выполнения функции fib: 7.724761962890625e-05 секунд
# Время выполнения функции fib: 0.00015544891357421875 секунд
# Время выполнения функции fib: 0.000263214111328125 секунд
# Время выполнения функции fib: 0.00046372413635253906 секунд
# Время выполнения функции fib: 0.0007467269897460938 секунд
# Время выполнения функции fib: 0.0013318061828613281 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 3.719329833984375e-05 секунд
# Время выполнения функции fib: 7.390975952148438e-05 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 3.814697265625e-05 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 1.430511474609375e-06 секунд
# Время выполнения функции fib: 0.029097795486450195 секунд
# Время выполнения функции fib: 0.029175996780395508 секунд
# Время выполнения функции fib: 0.02926325798034668 секунд
# Время выполнения функции fib: 0.029387712478637695 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 6.031990051269531e-05 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 5.888938903808594e-05 секунд
# Время выполнения функции fib: 0.00011229515075683594 секунд
# Время выполнения функции fib: 0.00022912025451660156 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 5.793571472167969e-05 секунд
# Время выполнения функции fib: 0.00011658668518066406 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 5.698204040527344e-05 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 9.5367431640625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 5.745887756347656e-05 секунд
# Время выполнения функции fib: 0.00012063980102539062 секунд
# Время выполнения функции fib: 0.0002334117889404297 секунд
# Время выполнения функции fib: 0.0004048347473144531 секунд
# Время выполнения функции fib: 0.0006897449493408203 секунд
# Время выполнения функции fib: 0.03013300895690918 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 9.5367431640625e-07 секунд
# Время выполнения функции fib: 0.002952098846435547 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 9.5367431640625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 6.365776062011719e-05 секунд
# Время выполнения функции fib: 0.00013828277587890625 секунд
# Время выполнения функции fib: 0.0031490325927734375 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 5.888938903808594e-05 секунд
# Время выполнения функции fib: 0.00011610984802246094 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 0.00010609626770019531 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 1.1920928955078125e-06 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 5.984306335449219e-05 секунд
# Время выполнения функции fib: 0.0001163482666015625 секунд
# Время выполнения функции fib: 0.00027632713317871094 секунд
# Время выполнения функции fib: 0.00044226646423339844 секунд
# Время выполнения функции fib: 0.0036470890045166016 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 5.888938903808594e-05 секунд
# Время выполнения функции fib: 0.00011491775512695312 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 5.650520324707031e-05 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 6.794929504394531e-05 секунд
# Время выполнения функции fib: 0.0001380443572998047 секунд
# Время выполнения функции fib: 0.0002512931823730469 секунд
# Время выполнения функции fib: 0.00042128562927246094 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 6.008148193359375e-05 секунд
# Время выполнения функции fib: 7.152557373046875e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 5.936622619628906e-05 секунд
# Время выполнения функции fib: 0.00011706352233886719 секунд
# Время выполнения функции fib: 0.00024080276489257812 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 6.246566772460938e-05 секунд
# Время выполнения функции fib: 0.00012135505676269531 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 2.384185791015625e-07 секунд
# Время выполнения функции fib: 5.7220458984375e-05 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 1.1920928955078125e-06 секунд
# Время выполнения функции fib: 4.76837158203125e-07 секунд
# Время выполнения функции fib: 5.9604644775390625e-05 секунд
# Время выполнения функции fib: 0.00011801719665527344 секунд
# Время выполнения функции fib: 0.00023317337036132812 секунд
# Время выполнения функции fib: 0.00040984153747558594 секунд
# Время выполнения функции fib: 0.0007059574127197266 секунд
# Время выполнения функции fib: 0.0011832714080810547 секунд
# Время выполнения функции fib: 0.004885435104370117 секунд
# Время выполнения функции fib: 0.03507423400878906 секунд
# Время выполнения функции fib: 0.0364534854888916 секунд
# 55

# %%
@benchmark
@memo
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
import functools

def benchmark(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print(f'Время выполнения функции {func.__name__}: {end - start} секунд')
        return result
    return wrapper

result = fib(10)
print(result)
# Out:
# Время выполнения функции fmemo: 1.9073486328125e-06 секунд
# Время выполнения функции fmemo: 3.5762786865234375e-06 секунд
# Время выполнения функции fmemo: 0.002095460891723633 секунд
# Время выполнения функции fmemo: 1.6689300537109375e-06 секунд
# Время выполнения функции fmemo: 1.9073486328125e-06 секунд
# Время выполнения функции fmemo: 0.0010025501251220703 секунд
# Время выполнения функции fmemo: 0.004035472869873047 секунд
# Время выполнения функции fmemo: 1.6689300537109375e-06 секунд
# Время выполнения функции fmemo: 1.6689300537109375e-06 секунд
# Время выполнения функции fmemo: 0.0009691715240478516 секунд
# Время выполнения функции fmemo: 0.007911443710327148 секунд
# Время выполнения функции fmemo: 7.152557373046875e-07 секунд
# Время выполнения функции fmemo: 7.152557373046875e-07 секунд
# Время выполнения функции fmemo: 4.792213439941406e-05 секунд
# Время выполнения функции fmemo: 0.008222341537475586 секунд
# Время выполнения функции fmemo: 9.5367431640625e-07 секунд
# Время выполнения функции fmemo: 4.76837158203125e-07 секунд
# Время выполнения функции fmemo: 3.838539123535156e-05 секунд
# Время выполнения функции fmemo: 0.008322477340698242 секунд
# 55
